# %%
import torch
import torch.nn as nn

import numpy as np
from torch.nn.utils.rnn import pad_sequence
torch.manual_seed(0)
np.random.seed(0)

# %%
from model import QNetwork, get_network_input
from Game import GameEnvironment
from collections import deque
from replay_buffer import ReplayMemory
import time

# TODO: Create an instance for model with input_dim = 10, hidden_dim = 20, output_dim = 5

model = QNetwork(input_dim=10,hidden_dim=20,output_dim=5)
epsilon = 0.1
grid_size = 15 
GAMMA = 0.9

board = GameEnvironment(grid_size, nothing=0, dead=-1, apple=1)
memory = ReplayMemory(1000)  
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-5)

# %%
import torch
import numpy as np

# Assuming you have defined the `Board` class and `Memory` class somewhere in your code

def run_episode(num_games):
    run = True
    games_played = 0
    total_reward = 0    
    episode_games = 0
    snake_len_array = []
    
    while run:
        # TODO: Get state
        state = get_network_input(board.snake,board.apple)

        # Get the action from the model
        action_0 = model(state)

        # Compare a random number with epsilon and find out the next action
        random_num = np.random.rand()
        next_action = np.random.randint(0, 4) if random_num < epsilon else torch.argmax(action_0)
        
        reward, done, len_of_snake = board.update_board_state(next_action)
        
        # Get next state
        next_state = get_network_input(board.snake,board.apple)

        
        memory.push(state, next_action, reward, next_state, done)

        # Update total reward
        total_reward += reward
        
        episode_games += 1
        
        if board.game_over:
            games_played += 1
            snake_len_array.append(len_of_snake)
            board.reset_game()
            
            if num_games == games_played:
                run = False
                
    avg_len_of_snake = np.mean(snake_len_array)
    max_len_of_snake = np.max(snake_len_array)
    
    return total_reward, avg_len_of_snake, max_len_of_snake

# %%
MSE = nn.MSELoss()
def learn(num_updates, batch_size):
    
    total_loss = 0
    
    for i in range(num_updates):

        optimizer.zero_grad()
        sample = memory.sample(batch_size)
            
        states, actions, rewards, next_states, dones = sample
        states = torch.cat([x.unsqueeze(0) for x in states], dim=0) 
        actions = torch.LongTensor(actions) 
        rewards = torch.FloatTensor(rewards) 
        next_states = torch.cat([x.unsqueeze(0) for x in next_states]) 
        dones = torch.FloatTensor(dones) 
        
        # TODO: Get Q values for current state
        q_local = model(states)
        
        
        # TODO: Get Q values for next state
        next_q_value = model(next_states)

        Q_expected  = q_local.gather(1, actions.unsqueeze(0).transpose(0,1)).transpose(0,1).squeeze(0)  
        
        Q_targets_next = torch.max(next_q_value, 1)[0]*(torch.ones(dones.size()) - dones)
        
        # TODO: Calculate Q targets for current state
        Q_targets  = rewards + (GAMMA * Q_targets_next) 
        
        loss = MSE(Q_expected, Q_targets)
        
        total_loss += loss
        loss.backward()
        optimizer.step()
        
    return total_loss

# %%
num_episodes = 3000 
num_updates = 200 
print_every = 100
games_in_episode = 30
batch_size = 20


def train():
    
    scores_deque = deque(maxlen=100)
    scores_array = []
    avg_scores_array = []    
    
    avg_len_array = []
    avg_max_len_array = []
    
    time_start = time.time()
    
    
    for i_episode in range(num_episodes+1):
        
        # TODO: Run an episode
        score, avg_len, max_len = run_episode(games_in_episode)
        
        scores_deque.append(score)
        scores_array.append(score)
        avg_len_array.append(avg_len)
        avg_max_len_array.append(max_len)
        
        avg_score = np.mean(scores_deque)
        avg_scores_array.append(avg_score)
        
        # TODO: Learn from the episode
        total_loss = learn(num_updates,20)
        
        dt = (int)(time.time() - time_start)
        
        if i_episode % print_every == 0 and i_episode > 0:
            print('Ep.: {:6}, Loss: {:.3f}, Avg.Score: {:.2f}, Avg.LenOfSnake: {:.2f}, Max.LenOfSnake:  {:.2f} Time: {:02}:{:02}:{:02} '.\
                  format(i_episode, total_loss, score, avg_len, max_len, dt//3600, dt%3600//60, dt%60))
            
        memory.truncate()
        
        if i_episode % 250 == 0 and i_episode > 0:   
            torch.save(model.state_dict(), './model/Snake_{}'.format(i_episode))
            
    return scores_array, avg_scores_array, avg_len_array, avg_max_len_array    

# TODO: Train the model
scores, avg_scores, avg_len_of_snake, max_len_of_snake = train()
# Out:
# Ep.:    100, Loss: 2.181, Avg.Score: -27.00, Avg.LenOfSnake: 5.10, Max.LenOfSnake:  6.00 Time: 00:01:06
# Ep.:    200, Loss: 2.476, Avg.Score: -25.00, Avg.LenOfSnake: 5.17, Max.LenOfSnake:  7.00 Time: 00:02:09
# Ep.:    300, Loss: 2.485, Avg.Score: -27.00, Avg.LenOfSnake: 5.10, Max.LenOfSnake:  6.00 Time: 00:03:19
# Ep.:    400, Loss: 2.547, Avg.Score: -26.00, Avg.LenOfSnake: 5.13, Max.LenOfSnake:  6.00 Time: 00:04:35
# Ep.:    500, Loss: 1.955, Avg.Score: -26.00, Avg.LenOfSnake: 5.13, Max.LenOfSnake:  6.00 Time: 00:05:51
# Ep.:    600, Loss: 2.881, Avg.Score: -18.00, Avg.LenOfSnake: 5.40, Max.LenOfSnake:  9.00 Time: 00:07:18
# Ep.:    700, Loss: 2.516, Avg.Score: -20.00, Avg.LenOfSnake: 5.33, Max.LenOfSnake:  7.00 Time: 00:08:53
# Ep.:    800, Loss: 3.609, Avg.Score: 0.00, Avg.LenOfSnake: 6.00, Max.LenOfSnake:  9.00 Time: 00:10:39
# Ep.:    900, Loss: 2.851, Avg.Score: -8.00, Avg.LenOfSnake: 5.73, Max.LenOfSnake:  9.00 Time: 00:12:25
# Ep.:   1000, Loss: 2.733, Avg.Score: -5.00, Avg.LenOfSnake: 5.83, Max.LenOfSnake:  9.00 Time: 00:14:11
# Ep.:   1100, Loss: 3.698, Avg.Score: -3.00, Avg.LenOfSnake: 5.90, Max.LenOfSnake:  9.00 Time: 00:15:47
# Ep.:   1200, Loss: 4.486, Avg.Score: 3.00, Avg.LenOfSnake: 6.10, Max.LenOfSnake:  9.00 Time: 00:17:17
# Ep.:   1300, Loss: 4.571, Avg.Score: 8.00, Avg.LenOfSnake: 6.27, Max.LenOfSnake:  12.00 Time: 00:18:41
# Ep.:   1400, Loss: 4.475, Avg.Score: 0.00, Avg.LenOfSnake: 6.00, Max.LenOfSnake:  9.00 Time: 00:20:04
# Ep.:   1500, Loss: 4.796, Avg.Score: 10.00, Avg.LenOfSnake: 6.33, Max.LenOfSnake:  9.00 Time: 00:21:27
# Ep.:   1600, Loss: 5.052, Avg.Score: 20.00, Avg.LenOfSnake: 6.67, Max.LenOfSnake:  9.00 Time: 00:22:46
# Ep.:   1700, Loss: 6.087, Avg.Score: 6.00, Avg.LenOfSnake: 6.20, Max.LenOfSnake:  12.00 Time: 00:24:10
# Ep.:   1800, Loss: 5.580, Avg.Score: 49.00, Avg.LenOfSnake: 7.63, Max.LenOfSnake:  12.00 Time: 00:25:37
# Ep.:   1900, Loss: 5.963, Avg.Score: 28.00, Avg.LenOfSnake: 6.93, Max.LenOfSnake:  14.00 Time: 00:27:03
# Ep.:   2000, Loss: 5.828, Avg.Score: 33.00, Avg.LenOfSnake: 7.10, Max.LenOfSnake:  13.00 Time: 00:28:28
# Ep.:   2100, Loss: 5.464, Avg.Score: 54.00, Avg.LenOfSnake: 7.80, Max.LenOfSnake:  13.00 Time: 00:29:53
# Ep.:   2200, Loss: 5.242, Avg.Score: 49.00, Avg.LenOfSnake: 7.63, Max.LenOfSnake:  14.00 Time: 00:31:19
# Ep.:   2300, Loss: 5.343, Avg.Score: 47.00, Avg.LenOfSnake: 7.57, Max.LenOfSnake:  14.00 Time: 00:32:45
# Ep.:   2400, Loss: 4.637, Avg.Score: 41.00, Avg.LenOfSnake: 7.37, Max.LenOfSnake:  16.00 Time: 00:34:16
# Ep.:   2500, Loss: 4.177, Avg.Score: 71.00, Avg.LenOfSnake: 8.37, Max.LenOfSnake:  16.00 Time: 00:35:48
# Ep.:   2600, Loss: 5.083, Avg.Score: 61.00, Avg.LenOfSnake: 8.03, Max.LenOfSnake:  13.00 Time: 00:37:20
# Ep.:   2700, Loss: 4.724, Avg.Score: 101.00, Avg.LenOfSnake: 9.37, Max.LenOfSnake:  22.00 Time: 00:38:52
# Ep.:   2800, Loss: 6.401, Avg.Score: 72.00, Avg.LenOfSnake: 8.40, Max.LenOfSnake:  13.00 Time: 00:40:28
# Ep.:   2900, Loss: 4.551, Avg.Score: 97.00, Avg.LenOfSnake: 9.23, Max.LenOfSnake:  16.00 Time: 00:42:11
# Ep.:   3000, Loss: 4.638, Avg.Score: 76.00, Avg.LenOfSnake: 8.53, Max.LenOfSnake:  16.00 Time: 00:43:56

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print('length of scores: ', len(scores), ', len of avg_scores: ', len(avg_scores))

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores, label="Score")
plt.plot(np.arange(1, len(avg_scores)+1), avg_scores, label="Avg score on 100 episodes")
plt.legend(bbox_to_anchor=(1.05, 1)) 
plt.ylabel('Score')
plt.xlabel('Episodes #')
plt.show()
# Out:
# length of scores:  3001 , len of avg_scores:  3001

# %%
ax1 = fig.add_subplot(121)
plt.plot(np.arange(1, len(avg_len_of_snake)+1), avg_len_of_snake, label="Avg Len of Snake")
plt.plot(np.arange(1, len(max_len_of_snake)+1), max_len_of_snake, label="Max Len of Snake")
plt.legend(bbox_to_anchor=(1.05, 1)) 
plt.ylabel('Length of Snake')
plt.xlabel('Episodes #')
plt.show()
